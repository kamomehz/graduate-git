# %%
import numpy as np
import matplotlib.pyplot as plt
import glob, os
from sklearn import linear_model
import sklearn
from sklearn import preprocessing 
from sklearn.neural_network import MLPRegressor
import seaborn as sns
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_squared_log_error,r2_score
import pickle

# %%
datar=pd.read_csv("datart.csv").iloc[:,1:]
datar.columns.tolist()
# Out:
# ['city',
#  'country_x',
#  '2000_ls',
#  '2005_ls',
#  '2010_ls',
#  '2015_ls',
#  'region',
#  'p2000',
#  'p2005',
#  'p2010',
#  'p2015',
#  'g2000',
#  'g2005',
#  'g2010',
#  'g2015',
#  't2000',
#  't2005',
#  't2010',
#  't2015']

# %%
datar=pd.read_csv("datart.csv").iloc[:,1:]
cols = datar.columns.tolist()
cols = cols[:2]+cols[6:7]+cols[2:6] + cols[7:]
datar=datar[cols]
datar.head()
# Out:
#         city country_x region  2000_ls  2005_ls  2010_ls  2015_ls  \
# 0    Beijing     China   Asia     2202     3360     3503     4331
# 1   Shanghai     China   Asia     1730     3058     3286     4584
# 2  Guangzhou     China   Asia     1859     3103     3926     4927
# 3   Shenzhen     China   Asia     1180     2603     3502     3989
# 4      Wuhan     China   Asia     1348     1828     1991     2005
#
#          p2000        p2005        p2010        p2015        g2000  \
# 0  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 1  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 2  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 3  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 4  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
#
#          g2005     g2010       g2015      t2000     t2005      t2010  \
# 0  5364.250895  9121.348  13866.7332  24.788721  20.35345  18.659957
# 1  5364.250895  9121.348  13866.7332  24.788721  20.35345  18.659957
# 2  5364.250895  9121.348  13866.7332  24.788721  20.35345  18.659957
# 3  5364.250895  9121.348  13866.7332  24.788721  20.35345  18.659957
# 4  5364.250895  9121.348  13866.7332  24.788721  20.35345  18.659957
#
#        t2015
# 0  18.053836
# 1  18.053836
# 2  18.053836
# 3  18.053836
# 4  18.053836

# %%
datar.isnull().sum()
# Out:
# city         0
# country_x    0
# region       0
# 2000_ls      0
# 2005_ls      0
# 2010_ls      0
# 2015_ls      0
# p2000        0
# p2005        0
# p2010        0
# p2015        0
# g2000        0
# g2005        0
# g2010        0
# g2015        0
# t2000        0
# t2005        0
# t2010        0
# t2015        0
# dtype: int64

# %% [markdown]
# # Data mining

# %%
plt.figure(figsize=(16,12))
sns.heatmap(data=datar.iloc[:,2:].corr(),annot=True,fmt='.2f',cmap='YlOrBr')
plt.savefig("regressionHeatmap.png")
plt.show()

# %%
set(zip(range(20),datar.columns))
# Out:
# {(0, 'city'),
#  (1, 'country_x'),
#  (2, 'region'),
#  (3, '2000_ls'),
#  (4, '2005_ls'),
#  (5, '2010_ls'),
#  (6, '2015_ls'),
#  (7, 'p2000'),
#  (8, 'p2005'),
#  (9, 'p2010'),
#  (10, 'p2015'),
#  (11, 'g2000'),
#  (12, 'g2005'),
#  (13, 'g2010'),
#  (14, 'g2015'),
#  (15, 't2000'),
#  (16, 't2005'),
#  (17, 't2010'),
#  (18, 't2015')}

# %%
y5=pd.DataFrame(datar.iloc[:,[0,1,3,4,7,8,11,12]])
# n5=pd.DataFrame({"radius":coor2.reshape(-1)})
n5=pd.DataFrame({"year":np.ones(114)*5})
y5=pd.concat([y5,n5],axis=1)
y5
# Out:
#            city country_x  2000_ls  2005_ls        p2000        p2005  \
# 0       Beijing     China     2202     3360  1269.116737  1307.593489
# 1      Shanghai     China     1730     3058  1269.116737  1307.593489
# 2     Guangzhou     China     1859     3103  1269.116737  1307.593489
# 3      Shenzhen     China     1180     2603  1269.116737  1307.593489
# 4         Wuhan     China     1348     1828  1269.116737  1307.593489
# ..          ...       ...      ...      ...          ...          ...
# 109    Kingston   Jamaica     3389     3822     2.581648     2.681653
# 110   Ljubljana  Slovenia      157      150     1.985406     2.002084
# 111        Riga    Latvia      189      226     2.384972     2.305528
# 112     Tallinn   Estonia      126      133     1.370749     1.345857
# 113  Georgetown    Guyana     1615     1802     0.733101     0.746235
#
#            g2000        g2005  year
# 0    3368.066879  5364.250895   5.0
# 1    3368.066879  5364.250895   5.0
# 2    3368.066879  5364.250895   5.0
# 3    3368.066879  5364.250895   5.0
# 4    3368.066879  5364.250895   5.0
# ..           ...          ...   ...
# 109    16.917373    18.625539   5.0
# 110    39.313614    46.962273   5.0
# 111    20.258867    30.028194   5.0
# 112    15.067488    22.275160   5.0
# 113     1.827184     1.892736   5.0
#
# [114 rows x 9 columns]

# %%
y5=pd.DataFrame(datar.iloc[:,[0,1,3,4,7,8,11,12,15,16]])
# n5=pd.DataFrame({"radius":coor2.reshape(-1)})
n5=pd.DataFrame({"year":np.ones(114)*5})
y5=pd.concat([y5,n5],axis=1)
y5.columns=['city', 'country', 'ls1', 'ls2', "p1",'p2', "g1",'g2',"t1","t2", 'year']

y10=pd.DataFrame(datar.iloc[:,[0,1,3,5,7,9,11,13,15,17]])
n10=pd.DataFrame({"year":np.ones(114)*10})
y10=pd.concat([y10,n10],axis=1)
y10.columns=['city', 'country','ls1', 'ls2',  "p1",'p2', "g1",'g2',"t1","t2", 'year']

y15=pd.DataFrame(datar.iloc[:,[0,1,3,6,7,10,11,14,15,18]])
n15=pd.DataFrame({"year":np.ones(114)*15})
y15=pd.concat([y15,n15],axis=1)
y15.columns=['city', 'country','ls1', 'ls2',  "p1",'p2', "g1",'g2',"t1","t2", 'year']

# %%
data2=pd.concat([y5,y10,y15], axis=0)
data2#.head()
# Out:
#            city   country   ls1   ls2           p1           p2           g1  \
# 0       Beijing     China  2202  3360  1269.116737  1307.593489  3368.066879
# 1      Shanghai     China  1730  3058  1269.116737  1307.593489  3368.066879
# 2     Guangzhou     China  1859  3103  1269.116737  1307.593489  3368.066879
# 3      Shenzhen     China  1180  2603  1269.116737  1307.593489  3368.066879
# 4         Wuhan     China  1348  1828  1269.116737  1307.593489  3368.066879
# ..          ...       ...   ...   ...          ...          ...          ...
# 109    Kingston   Jamaica  3389  3961     2.581648     2.783070    16.917373
# 110   Ljubljana  Slovenia   157   155     1.985406     2.065011    39.313614
# 111        Riga    Latvia   189   203     2.384972     2.183121    20.258867
# 112     Tallinn   Estonia   126   134     1.370749     1.334214    15.067488
# 113  Georgetown    Guyana  1615  1932     0.733101     0.761679     1.827184
#
#               g2         t1         t2  year
# 0    5364.250895  24.788721  20.353450   5.0
# 1    5364.250895  24.788721  20.353450   5.0
# 2    5364.250895  24.788721  20.353450   5.0
# 3    5364.250895  24.788721  20.353450   5.0
# 4    5364.250895  24.788721  20.353450   5.0
# ..           ...        ...        ...   ...
# 109    19.970800  32.149270  24.598957  15.0
# 110    55.247400  15.773171  14.669957  15.0
# 111    35.410600  17.856532  15.094305  15.0
# 112    27.707200  17.582938  16.130462  15.0
# 113     3.023400  35.655504  29.332371  15.0
#
# [342 rows x 11 columns]

# %%
plt.figure(figsize=(16,12))
sns.heatmap(data=data2.iloc[:,2:].corr(),annot=True,fmt='.2f',cmap='YlOrBr')
plt.show()

# %%
data2.columns.values
# Out:
# array(['city', 'country', 'ls1', 'ls2', 'p1', 'p2', 'g1', 'g2', 't1',
#        't2', 'year'], dtype=object)

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(16,10))
plt.subplots_adjust(hspace=0.4)

corr_to_gdp = pd.Series()
for col in data2.columns.values[2:]:
    if ((col!='ls2')&(col!='Regional_label')):
        corr_to_gdp[col] = data2['ls2'].corr(data2[col])
abs_corr_to_gdp = corr_to_gdp.abs().sort_values(ascending=False)
corr_to_gdp = corr_to_gdp.loc[abs_corr_to_gdp.index]

for i in range(3):
    for j in range(3):
        sns.regplot(x=corr_to_gdp.index.values[i*3+j], y='ls2', data=data2,
                   ax=axes[i,j], fit_reg=False, marker='.')
        title = 'correlation='+str(corr_to_gdp[i*3+j])
        axes[i,j].set_title(title)
axes[1,2].set_xlim(0,102)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-371d63be17d5> in <module>
#      11 for i in range(3):
#      12     for j in range(3):
# ---> 13         sns.regplot(x=corr_to_gdp.index.values[i*3+j], y='ls2', data=data2,
#      14                    ax=axes[i,j], fit_reg=False, marker='.')
#      15         title = 'correlation='+str(corr_to_gdp[i*3+j])
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %% [markdown]
# # Modeling

# %%
def houkai(model,data,training_features):
    train, test = train_test_split(data, test_size=0.3, shuffle=True)
    target = "ls2"
    train_X = train[training_features]
    train_Y = train[target]
    test_X = test[training_features]
    test_Y = test[target]
    model.fit(train_X, train_Y)

    train_pred_Y = model.predict(train_X)
    test_pred_Y = model.predict(test_X)
    train_pred_Y = pd.Series(train_pred_Y.clip(0, train_pred_Y.max()), index=train_Y.index)
    test_pred_Y = pd.Series(test_pred_Y.clip(0, test_pred_Y.max()), index=test_Y.index)

    rmse_train = np.sqrt(mean_squared_error(train_pred_Y, train_Y))
    msle_train = mean_squared_log_error(train_pred_Y, train_Y)
    rmse_test = np.sqrt(mean_squared_error(test_pred_Y, test_Y))
    msle_test = mean_squared_log_error(test_pred_Y, test_Y)
    r2 = r2_score(test_Y,test_pred_Y)

    print('rmse_train:',rmse_train,'msle_train:',msle_train)
    print('rmse_test:',rmse_test,'msle_test:',msle_test)
    print("r2_score:",r2)

    resultPlot=np.ones((test_Y.shape[0],2))
    resultPlot[:,0]=test_Y.values
    resultPlot[:,1]=test_pred_Y.values
    
    plt.figure(figsize=(5,5))
    plt.scatter(test_Y.values,test_pred_Y.values)
    plt.xlabel("Real")
    plt.ylabel("Predict")
    return model

# %%
data3=data2.copy()
# data3['ls2']=data3['ls2']/data3['ls1']
# training_features = ['ls1','g1', 'g2','year']
training_features = ['ls1','g1', 'g2','p1','p2','year']#,'Regional_label']
# model = RandomForestRegressor()
model = linear_model.Ridge(alpha=.5)
temp=houkai(model,data3,training_features)
model = LinearRegression()
temp=houkai(model,data3,training_features)
# Out:
# rmse_train: 358.66525916966776 msle_train: 0.07568575964649775
# rmse_test: 347.717734633518 msle_test: 0.08266813058426428
# r2_score: 0.9308134992749316
# rmse_train: 359.40722643182323 msle_train: 0.08302644591427732
# rmse_test: 348.1436937055068 msle_test: 0.08178839657977027
# r2_score: 0.9237270330661663

# %% [markdown]
# # Without test set

# %%
def houkai3(model,data,training_features):
    train_X = data[training_features]
    target = "ls2"
    train_Y = data[target]
    test_X = train_X
    test_Y = train_Y
    model.fit(train_X, train_Y)

    train_pred_Y = model.predict(train_X)
    test_pred_Y = model.predict(test_X)
    train_pred_Y = pd.Series(train_pred_Y.clip(0, train_pred_Y.max()), index=train_Y.index)
    test_pred_Y = pd.Series(test_pred_Y.clip(0, test_pred_Y.max()), index=test_Y.index)

#     rmse_train = np.sqrt(mean_squared_error(train_pred_Y, train_Y))
#     msle_train = mean_squared_log_error(train_pred_Y, train_Y)
#     rmse_test = np.sqrt(mean_squared_error(test_pred_Y, test_Y))
#     msle_test = mean_squared_log_error(test_pred_Y, test_Y)
#     print('rmse_train:',rmse_train,'msle_train:',msle_train)
#     print('rmse_test:',rmse_test,'msle_test:',msle_test)

    r2 = r2_score(test_Y,test_pred_Y)
    print("r2_score:",r2)

    resultPlot=np.ones((test_Y.shape[0],2))
    resultPlot[:,0]=test_Y.values
    resultPlot[:,1]=test_pred_Y.values

    plt.figure(figsize=(8,8))
    plt.scatter(test_Y.values,test_pred_Y.values,s=2)
    plt.xlabel("Real")
    plt.ylabel("Predict")
    return model

# %%
with open('LR3.pickle', 'wb') as fw:
    pickle.dump(LR3, fw)
with open('RF3.pickle', 'wb') as fw:
    pickle.dump(RF3, fw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0fc923940c98> in <module>
#       1 with open('LR3.pickle', 'wb') as fw:
# ----> 2     pickle.dump(LR3, fw)
#       3 with open('RF3.pickle', 'wb') as fw:
#       4     pickle.dump(RF3, fw)
#
# NameError: name 'LR3' is not defined

# %%
LR.coef__
# Out:
# array([ 1.10723151, -0.09255839,  0.07421364,  1.85616245, -1.62217053,
#         9.87551079, -2.48735376, 14.29246749])

# %%
data4=data2.copy()
training_features = ['ls1','g1', 'g2','p1','p2',"t1","t2",'year']
# model = RandomForestRegressor()
# RF=houkai3(model,data4,training_features)
# model = linear_model.Ridge(alpha=.5)
# RI=houkai3(model,data4,training_features)

model = LinearRegression()
LR=houkai3(model,data4,training_features)
# Out:
# r2_score: 0.9301490583686988

# %%
data4=data2.copy()
training_features = ['ls1','g1', 'g2','year']

model = LinearRegression()
LR=houkai3(model,data4,training_features)
with open('LR-2015-gdp.pickle', 'wb') as fw:
    pickle.dump(LR, fw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-61db33b014ea> in <module>
# ----> 1 data4=data2.copy()
#       2 training_features = ['ls1','g1', 'g2','year']
#       3
#       4 model = LinearRegression()
#       5 LR=houkai3(model,data4,training_features)
#
# NameError: name 'data2' is not defined

# %%
with open('LR-2015.pickle', 'wb') as fw:
    pickle.dump(LR, fw)

# %%
with open('LR.pickle', 'wb') as fw:
    pickle.dump(LR, fw)
with open('RF.pickle', 'wb') as fw:
    pickle.dump(RF, fw)
with open('RI.pickle', 'wb') as fw:
    pickle.dump(RI, fw)

# %%
data4=data2.copy()
data4['ls2']=data4['ls2']/data4['ls1']
data4['p2']=data4['p2']/data4['p1']
training_features = ['ls1','g1', 'g2','p1','p2','year']
model = RandomForestRegressor()
RF2=houkai3(model,data4,training_features)
model = LinearRegression()
LR2=houkai3(model,data4,training_features)

# %%
with open('LR2.pickle', 'wb') as fw:
    pickle.dump(LR2, fw)
with open('RF2.pickle', 'wb') as fw:
    pickle.dump(RF2, fw)

# %%
data4=data2.copy()
data5=data4[data4.duplicated("country")==False].reset_index().iloc[:,1:]

# data4['ls2']=data4['ls2']/data4['ls1']
# data4['ls1']=np.log(data4['ls1'])
# data4['ls2']=np.log(data4['ls2'])
training_features = ['ls1','g1', 'g2','p1','p2','year']
model = RandomForestRegressor()
RF4=houkai3(model,data5,training_features)
model = LinearRegression()
LR4=houkai3(model,data5,training_features)

# %%
with open('LR4.pickle', 'wb') as fw:
    pickle.dump(LR4, fw)
with open('RF4.pickle', 'wb') as fw:
    pickle.dump(RF4, fw)

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob, os
from sklearn import linear_model
import sklearn
from sklearn import preprocessing 
from sklearn.neural_network import MLPRegressor
import seaborn as sns
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_squared_log_error,r2_score
import pickle

# %%
datar=pd.read_csv("datar.csv").iloc[:,1:]
datar.columns.tolist()
# Out:
# ['city',
#  'country_x',
#  '2000_ls',
#  '2005_ls',
#  '2010_ls',
#  '2015_ls',
#  'region',
#  'p2000',
#  'p2005',
#  'p2010',
#  'p2015',
#  'g2000',
#  'g2005',
#  'g2010',
#  'g2015']

# %%
datar=pd.read_csv("datar.csv").iloc[:,1:]
cols = datar.columns.tolist()
cols = cols[:2]+cols[5:7]+cols[2:5] + cols[7:]
datar=datar[cols]
datar.head()
# Out:
#         city country_x  2015_ls region  2000_ls  2005_ls  2010_ls  \
# 0    Beijing     China     4331   Asia     2202     3360     3503
# 1   Shanghai     China     4584   Asia     1730     3058     3286
# 2  Guangzhou     China     4927   Asia     1859     3103     3926
# 3   Shenzhen     China     3989   Asia     1180     2603     3502
# 4      Wuhan     China     2005   Asia     1348     1828     1991
#
#          p2000        p2005        p2010        p2015        g2000  \
# 0  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 1  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 2  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 3  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
# 4  1269.116737  1307.593489  1341.335152  1361.908626  3368.066879
#
#          g2005     g2010       g2015
# 0  5364.250895  9121.348  13866.7332
# 1  5364.250895  9121.348  13866.7332
# 2  5364.250895  9121.348  13866.7332
# 3  5364.250895  9121.348  13866.7332
# 4  5364.250895  9121.348  13866.7332

# %%
datar.isnull().sum()
# Out:
# city         0
# country_x    0
# 2015_ls      0
# region       0
# 2000_ls      0
# 2005_ls      0
# 2010_ls      0
# p2000        0
# p2005        0
# p2010        0
# p2015        0
# g2000        0
# g2005        0
# g2010        0
# g2015        0
# dtype: int64

# %% [markdown]
# # Data mining

# %%
plt.figure(figsize=(16,12))
sns.heatmap(data=datar.iloc[:,2:].corr(),annot=True,fmt='.2f',cmap='YlOrBr')
plt.show()

# %%
set(zip(range(20),datar.columns))
# Out:
# {(0, 'city'),
#  (1, 'country_x'),
#  (2, 'region'),
#  (3, 'Regional_label'),
#  (4, '2000_ls'),
#  (5, '2005_ls'),
#  (6, '2010_ls'),
#  (7, 'p2000'),
#  (8, 'p2005'),
#  (9, 'p2010'),
#  (10, 'g2000'),
#  (11, 'g2005'),
#  (12, 'g2010')}

# %%
y5=pd.DataFrame(datar.iloc[:,[0,1,3,4,6,7,8,10,11]])
# n5=pd.DataFrame({"radius":coor2.reshape(-1)})
n5=pd.DataFrame({"year":np.ones(114)*5})
y5=pd.concat([y5,n5],axis=1)
y5.columns=['city', 'country','Regional_label', 'ls1', 'ls2', "p1",'p2', "g1",'g2', 'year']

y10=pd.DataFrame(datar.iloc[:,[0,1,3,4,6,7,9,10,12]])
n10=pd.DataFrame({"year":np.ones(114)*10})
y10=pd.concat([y10,n10],axis=1)
y10.columns=['city', 'country','Regional_label', 'ls1', 'ls2',  "p1",'p2', "g1",'g2', 'year']

# %%
data2=pd.concat([y5,y10], axis=0)
data2.head()
# Out:
#         city country  Regional_label   ls1   ls2           p1           p2  \
# 0    Beijing   China               2  2202  3503  1269.116737  1307.593489
# 1   Shanghai   China               2  1730  3286  1269.116737  1307.593489
# 2  Guangzhou   China               2  1859  3926  1269.116737  1307.593489
# 3   Shenzhen   China               2  1180  3502  1269.116737  1307.593489
# 4      Wuhan   China               2  1348  1991  1269.116737  1307.593489
#
#             g1           g2  year
# 0  3368.066879  5364.250895   5.0
# 1  3368.066879  5364.250895   5.0
# 2  3368.066879  5364.250895   5.0
# 3  3368.066879  5364.250895   5.0
# 4  3368.066879  5364.250895   5.0

# %%
plt.figure(figsize=(16,12))
sns.heatmap(data=data2.iloc[:,2:].corr(),annot=True,fmt='.2f',cmap='YlOrBr')
plt.show()

# %%
data2.columns.values
# Out:
# array(['city', 'country', 'Regional_label', 'ls1', 'ls2', 'p1', 'p2',
#        'g1', 'g2', 'year'], dtype=object)

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(16,10))
plt.subplots_adjust(hspace=0.4)

corr_to_gdp = pd.Series()
for col in data2.columns.values[2:]:
    if ((col!='ls2')&(col!='Regional_label')):
        corr_to_gdp[col] = data2['ls2'].corr(data2[col])
abs_corr_to_gdp = corr_to_gdp.abs().sort_values(ascending=False)
corr_to_gdp = corr_to_gdp.loc[abs_corr_to_gdp.index]

for i in range(2):
    for j in range(3):
        sns.regplot(x=corr_to_gdp.index.values[i*3+j], y='ls2', data=data2,
                   ax=axes[i,j], fit_reg=False, marker='.')
        title = 'correlation='+str(corr_to_gdp[i*3+j])
        axes[i,j].set_title(title)
axes[1,2].set_xlim(0,102)
plt.show()

# %% [markdown]
# # Modeling

# %%
def houkai(model,data,training_features):
    train, test = train_test_split(data, test_size=0.3, shuffle=True)
    target = "ls2"
    train_X = train[training_features]
    train_Y = train[target]
    test_X = test[training_features]
    test_Y = test[target]
    model.fit(train_X, train_Y)

    train_pred_Y = model.predict(train_X)
    test_pred_Y = model.predict(test_X)
    train_pred_Y = pd.Series(train_pred_Y.clip(0, train_pred_Y.max()), index=train_Y.index)
    test_pred_Y = pd.Series(test_pred_Y.clip(0, test_pred_Y.max()), index=test_Y.index)

    rmse_train = np.sqrt(mean_squared_error(train_pred_Y, train_Y))
    msle_train = mean_squared_log_error(train_pred_Y, train_Y)
    rmse_test = np.sqrt(mean_squared_error(test_pred_Y, test_Y))
    msle_test = mean_squared_log_error(test_pred_Y, test_Y)
    r2 = r2_score(test_Y,test_pred_Y)

    print('rmse_train:',rmse_train,'msle_train:',msle_train)
    print('rmse_test:',rmse_test,'msle_test:',msle_test)
    print("r2_score:",r2)

    resultPlot=np.ones((test_Y.shape[0],2))
    resultPlot[:,0]=test_Y.values
    resultPlot[:,1]=test_pred_Y.values
    
    plt.figure(figsize=(5,5))
    plt.scatter(test_Y.values,test_pred_Y.values)
    plt.xlabel("Real")
    plt.ylabel("Predict")
    return model

# %%
data3=data2.copy()
# data3['ls2']=data3['ls2']/data3['ls1']
# training_features = ['ls1','g1', 'g2','year']
training_features = ['ls1','g1', 'g2','p1','p2','year','Regional_label']
# model = RandomForestRegressor()
model = linear_model.Ridge(alpha=.5)
temp=houkai(model,data3,training_features)
model = LinearRegression()
temp=houkai(model,data3,training_features)
# Out:
# rmse_train: 365.2392807440831 msle_train: 0.062090542178238756
# rmse_test: 264.3763247006693 msle_test: 0.056936963413936295
# r2_score: 0.9576036515684928
# rmse_train: 327.24666528126795 msle_train: 0.04643360458515823
# rmse_test: 376.9441863990335 msle_test: 0.08332149779617656
# r2_score: 0.8771294545714234

# %% [markdown]
# # Without test set

# %%
def houkai3(model,data,training_features):
    train_X = data[training_features]
    target = "ls2"
    train_Y = data[target]
    test_X = train_X
    test_Y = train_Y
    model.fit(train_X, train_Y)

    train_pred_Y = model.predict(train_X)
    test_pred_Y = model.predict(test_X)
    train_pred_Y = pd.Series(train_pred_Y.clip(0, train_pred_Y.max()), index=train_Y.index)
    test_pred_Y = pd.Series(test_pred_Y.clip(0, test_pred_Y.max()), index=test_Y.index)

#     rmse_train = np.sqrt(mean_squared_error(train_pred_Y, train_Y))
#     msle_train = mean_squared_log_error(train_pred_Y, train_Y)
#     rmse_test = np.sqrt(mean_squared_error(test_pred_Y, test_Y))
#     msle_test = mean_squared_log_error(test_pred_Y, test_Y)
#     print('rmse_train:',rmse_train,'msle_train:',msle_train)
#     print('rmse_test:',rmse_test,'msle_test:',msle_test)

    r2 = r2_score(test_Y,test_pred_Y)
    print("r2_score:",r2)

    resultPlot=np.ones((test_Y.shape[0],2))
    resultPlot[:,0]=test_Y.values
    resultPlot[:,1]=test_pred_Y.values

    plt.figure(figsize=(3,3))
    plt.scatter(test_Y.values,test_pred_Y.values)
    plt.xlabel("Real")
    plt.ylabel("Predict")
    return model

# %%
with open('LR3.pickle', 'wb') as fw:
    pickle.dump(LR3, fw)
with open('RF3.pickle', 'wb') as fw:
    pickle.dump(RF3, fw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0fc923940c98> in <module>
#       1 with open('LR3.pickle', 'wb') as fw:
# ----> 2     pickle.dump(LR3, fw)
#       3 with open('RF3.pickle', 'wb') as fw:
#       4     pickle.dump(RF3, fw)
#
# NameError: name 'LR3' is not defined

# %%
data4=data2.copy()
training_features = ['ls1','g1', 'g2','p1','p2','year']
# model = RandomForestRegressor()
# RF=houkai3(model,data4,training_features)
# model = linear_model.Ridge(alpha=.5)
# RI=houkai3(model,data4,training_features)

model = LinearRegression()
LR=houkai3(model,data4,training_features)
# Out:
# r2_score: 0.9299121721342609

# %%
with open('LR.pickle', 'wb') as fw:
    pickle.dump(LR, fw)
with open('RF.pickle', 'wb') as fw:
    pickle.dump(RF, fw)
with open('RI.pickle', 'wb') as fw:
    pickle.dump(RI, fw)

# %%
data4=data2.copy()
data4['ls2']=data4['ls2']/data4['ls1']
data4['p2']=data4['p2']/data4['p1']
training_features = ['ls1','g1', 'g2','p1','p2','year']
model = RandomForestRegressor()
RF2=houkai3(model,data4,training_features)
model = LinearRegression()
LR2=houkai3(model,data4,training_features)

# %%
with open('LR2.pickle', 'wb') as fw:
    pickle.dump(LR2, fw)
with open('RF2.pickle', 'wb') as fw:
    pickle.dump(RF2, fw)

# %%
data4=data2.copy()
data5=data4[data4.duplicated("country")==False].reset_index().iloc[:,1:]

# data4['ls2']=data4['ls2']/data4['ls1']
# data4['ls1']=np.log(data4['ls1'])
# data4['ls2']=np.log(data4['ls2'])
training_features = ['ls1','g1', 'g2','p1','p2','year']
model = RandomForestRegressor()
RF4=houkai3(model,data5,training_features)
model = LinearRegression()
LR4=houkai3(model,data5,training_features)

# %%
with open('LR4.pickle', 'wb') as fw:
    pickle.dump(LR4, fw)
with open('RF4.pickle', 'wb') as fw:
    pickle.dump(RF4, fw)

# %%
data2
# Out:
#            city   country  Regional_label   ls1   ls2           p1  \
# 0       Beijing     China               2  2202  3503  1269.116737
# 1      Shanghai     China               2  1730  3286  1269.116737
# 2     Guangzhou     China               2  1859  3926  1269.116737
# 3      Shenzhen     China               2  1180  3502  1269.116737
# 4         Wuhan     China               2  1348  1991  1269.116737
# ..          ...       ...             ...   ...   ...          ...
# 109    Kingston   Jamaica               1  3389  3921     2.581648
# 110   Ljubljana  Slovenia               3   157   152     1.985406
# 111        Riga    Latvia               3   189   223     2.384972
# 112     Tallinn   Estonia               3   126   132     1.370749
# 113  Georgetown    Guyana               1  1615  1814     0.733101
#
#               p2           g1           g2  year
# 0    1307.593489  3368.066879  5364.250895   5.0
# 1    1307.593489  3368.066879  5364.250895   5.0
# 2    1307.593489  3368.066879  5364.250895   5.0
# 3    1307.593489  3368.066879  5364.250895   5.0
# 4    1307.593489  3368.066879  5364.250895   5.0
# ..           ...          ...          ...   ...
# 109     2.741052    16.917373    18.598366  10.0
# 110     2.029680    39.313614    51.322855  10.0
# 111     2.252060    20.258867    29.018887  10.0
# 112     1.341140    15.067488    22.192321  10.0
# 113     0.754493     1.827184     2.324123  10.0
#
# [228 rows x 10 columns]
